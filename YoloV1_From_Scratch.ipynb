# %% [markdown]
# clone the pproject using ssh to colab

# %%
# !git clone https://Colab-Yolo:glpat-xsGPGeJpFj3-ey57HYZx@gitlab.com/magshimim112/object-detection

# %% [markdown]
# my personal api key:
# Colab-Yolo
# glpat-xsGPGeJpFj3-ey57HYZx

# %% [markdown]
# if clone didnt work:
#
# *   Navigate to the GitLab User Preferences from the main menu.
# *   Click on Access Tokens in the left side menu.
# *   Give a descriptive name for your token and select the “read_api” scope.
# *   Click on the Create personal access token button.
#
# once you did these steps, run the command
#
# *   !git clone https://API_NAME:API_KEY@gitlab.com/magshimim112/object-detection
# *   replace API_NAME, API_KEY with your details

# %% [markdown]
# if this part doesnt work, you need to open your own kaggle account
#
#
# *   follow this tutorial: https://christianjmills.com/posts/kaggle-obtain-api-key-tutorial/
#
# download the key and upload it to drive, replace it with the existing kaggle api key

# %%
! pip install -q kaggle
! mkdir ~/.kaggle
! cp object-detection/kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d aladdinpersson/pascalvoc-yolo
# Out:
# ...
# 100% 4.30G/4.31G [00:29<00:00, 108MB/s]
# 100% 4.31G/4.31G [00:29<00:00, 155MB/s]

# %%
! unzip -q -n pascalvoc-yolo.zip -d /content/object-detection/data/

# %%
# !cp /content/object-detection/data/generate_csv.py /content/object-detection/

# %% [markdown]
# In case you want to upload your exsiting training file, get it from your drive, then copy it to local path

# %%
# In case you want to upload your exsiting training file, get it from your drive

from google.colab import drive
drive.mount('/content/drive')

# %%
# !cp drive/MyDrive/Training/500overfit.pth.tar .

# %% [markdown]
# run the model and save the weight(training) to your deive

# %%
# %run /content/object-detection/train.py
# !cp -rf 500overfit.pth.tar drive/MyDrive/Training/

# %% [markdown]
# show the result, can only be done if training is in local folder,
#
#
# *   for example: content/traingingFile.pth.tar

# %%
# %run /content/object-detection/infrence.py
# Out:
# Output hidden; open in https://colab.research.google.com to view.
